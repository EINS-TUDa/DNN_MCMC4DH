# %% [markdown]
# # Approximate steady state error
#
# We approximate the maximum error due to the steady state assumptions by following a 9 step work flow.
# The theory behind this approach is laied out in Appendix C of the paper.
#
#  1. draw initial demand
#  2. solve state equations (steady state)
#  3. modify demand (i.e. modify mass flows at demand)
#  4. solve hydraulic system with new mass flows
#  5. solve thermal system with new mass flows
#  6. solve steady state with new demands
#  7. compare thermal solution (5) and steady-state solution (6); i.e., compare temperatures at demands
#  8. store results over multiple runs and calculate means and variances

# %% [markdown]
# ### Imports:

# %%
import numpy as np
import tensorflow as tf
from libdnnmcmc.utility import load_scenario
from libdnnmcmc.steady_state_solvers import SE_solver, my_fixpoint_iteratror

SE, VM, d_prior_dist, _ = load_scenario('loop')
cycles = VM.cycles
FI = my_fixpoint_iteratror()
# Out:
# WARNING:tensorflow:From C:\Users\Andreas Bott\MeFlexWaerme\venv\lib\site-packages\tensorflow\python\autograph\pyct\static_analysis\liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %% [markdown]
# ### settings:

# %%
n_runs = 50
q_modifier = [0.7, 1.3]

# %% [markdown]
# ### setup:

# %%
n_modifier = len(q_modifier)
# init arrays to store results:
z_pattern = np.zeros((n_runs, n_modifier))
Ta_ss, Tb_ss, Tc_ss, Td_ss = np.zeros_like(z_pattern), np.zeros_like(z_pattern), np.zeros_like(z_pattern), np.zeros_like(z_pattern)
Ta_qss, Tb_qss, Tc_qss, Td_qss = np.zeros_like(z_pattern), np.zeros_like(z_pattern), np.zeros_like(z_pattern), np.zeros_like(z_pattern)

# define wrapper around solver:
solve_SE = SE_solver()
def _solve_SE(demands, SE):
    for dem in SE.demands.keys():
        ind = SE.dem_ind[dem]
        d = demands[ind]
        SE.Q_heat[ind].assign(d)
    solve_SE(SE, cycles)
    return tf.reduce_sum(SE.evaluate_state_equations('forwardpass')**2)

# %% [markdown]
# ### Analysis:

# %%
# 1 draw inital demand:
q_init = d_prior_dist.sample(n_runs)

for mod_ind, modifier in enumerate(q_modifier):
    q_new = q_init * modifier

    for run_ind in range(n_runs):

        # 2. solve state equations:
        psi = _solve_SE(q_init[run_ind, :], SE)

        # if the calculations did not converge reset the internal state of the SE object and try again
        if psi > 1.e-5:
            SE.set_init_state()
            psi = _solve_SE(q_init[run_ind, :], SE)
            if psi > 1.e-5:
                raise Exception(f'System did not converge with psi = {psi:4f}')

        # 3. modify mass flows according to demand:
        mf_init = tf.concat([SE.mf[SE.find_edge[k]] for k in SE.demands.keys()], axis=0)
        mf_new = mf_init * modifier

        #  4. solve hydraulic system with new mass flows
        FI.solve_mf(SE, mf_new, cycles)

        #  5. solve thermal system with new mass flows
        FI.solve_temp(SE)
        TA_qss = SE.T[SE.find_node['BS']]
        TB_qss = SE.T[SE.find_node['FS']]
        TC_qss = SE.T[SE.find_node['ES']]
        TD_qss = SE.T[SE.find_node['IS']]
        Ta_qss [run_ind, mod_ind], Tb_qss[run_ind, mod_ind], Tc_qss[run_ind, mod_ind], Td_qss[run_ind, mod_ind] = TA_qss, TB_qss, TC_qss, TD_qss

        #  6. solve steady state with new demands
        _solve_SE(q_new[run_ind,:], SE)

        #  7. compare thermal solution and steady-state solution
        TA_ss = SE.T[SE.find_node['BS']]
        TB_ss = SE.T[SE.find_node['FS']]
        TC_ss = SE.T[SE.find_node['ES']]
        TD_ss = SE.T[SE.find_node['IS']]

        # broadcast differences:
        print(f'T_diff Dem A: {TA_ss - TA_qss} \n'
              f'T_diff Dem B: {TB_ss - TB_qss} \n'
              f'T_diff Dem c: {TC_ss - TC_qss} \n'
              f'T_diff Dem D: {TD_ss - TD_qss} \n')

        #  8. save results for further analysis
        Ta_ss [run_ind, mod_ind], Tb_ss[run_ind, mod_ind], Tc_ss[run_ind, mod_ind], Td_ss[run_ind, mod_ind] = TA_ss, TB_ss, TC_ss, TD_ss
# Out:
# T_diff Dem A: [0.16886726]
#  T_diff Dem B: [1.74257629]
#  T_diff Dem c: [0.05077148]
#  T_diff Dem D: [0.16594071]
#
# T_diff Dem A: [0.20352625]
#  T_diff Dem B: [0.49475922]
#  T_diff Dem c: [0.04029388]
#  T_diff Dem D: [0.19316898]
#
# T_diff Dem A: [0.30564609]
#  T_diff Dem B: [0.97170311]
#  T_diff Dem c: [0.03681089]
#  T_diff Dem D: [0.19846425]
#
# T_diff Dem A: [0.16090781]
#  T_diff Dem B: [0.87829356]
#  T_diff Dem c: [0.04576766]
#  T_diff Dem D: [0.62237516]
#
# T_diff Dem A: [0.21125695]
#  T_diff Dem B: [-3.57838673]
#  T_diff Dem c: [0.05206049]
#  T_diff Dem D: [1.60035737]
#
# T_diff Dem A: [0.24622681]
#  T_diff Dem B: [0.71053122]
#  T_diff Dem c: [0.0362094]
#  T_diff Dem D: [0.13871323]
#
# T_diff Dem A: [0.28344678]
#  T_diff Dem B: [0.98361553]
#  T_diff Dem c: [0.03814324]
#  T_diff Dem D: [0.15163684]
#
# T_diff Dem A: [0.28553158]
#  T_diff Dem B: [0.75545733]
#  T_diff Dem c: [0.04720897]
#  T_diff Dem D: [0.16853765]
#
# T_diff Dem A: [0.1634733]
#  T_diff Dem B: [1.15117604]
#  T_diff Dem c: [0.04749986]
#  T_diff Dem D: [0.33834093]
#
# T_diff Dem A: [0.17287745]
#  T_diff Dem B: [1.5784323]
#  T_diff Dem c: [0.0428713]
#  T_diff Dem D: [0.32274927]
#
# T_diff Dem A: [0.29579767]
#  T_diff Dem B: [0.8285769]
#  T_diff Dem c: [0.029501]
#  T_diff Dem D: [0.20063354]
#
# T_diff Dem A: [0.29771858]
#  T_diff Dem B: [1.01626151]
#  T_diff Dem c: [0.03975923]
#  T_diff Dem D: [0.16193052]
#
# T_diff Dem A: [0.16225709]
#  T_diff Dem B: [0.9766505]
#  T_diff Dem c: [0.02675478]
#  T_diff Dem D: [0.27588503]
#
# T_diff Dem A: [0.34420275]
#  T_diff Dem B: [1.35715233]
#  T_diff Dem c: [0.0330718]
#  T_diff Dem D: [0.14701158]
#
# T_diff Dem A: [0.60819041]
#  T_diff Dem B: [1.82889849]
#  T_diff Dem c: [0.03194865]
#  T_diff Dem D: [0.13505299]
#
# T_diff Dem A: [0.18925683]
#  T_diff Dem B: [4.06568593]
#  T_diff Dem c: [0.04748744]
#  T_diff Dem D: [0.18589547]
#
# T_diff Dem A: [0.38723522]
#  T_diff Dem B: [0.91700124]
#  T_diff Dem c: [0.05526121]
#  T_diff Dem D: [0.25420686]
#
# T_diff Dem A: [0.28748018]
#  T_diff Dem B: [0.64352073]
#  T_diff Dem c: [0.0508293]
#  T_diff Dem D: [0.31341913]
#
# T_diff Dem A: [0.20401547]
#  T_diff Dem B: [0.72531011]
#  T_diff Dem c: [0.03337782]
#  T_diff Dem D: [0.31241456]
#
# T_diff Dem A: [0.28884174]
#  T_diff Dem B: [0.95565339]
#  T_diff Dem c: [0.03280294]
#  T_diff Dem D: [0.15662956]
#
# T_diff Dem A: [0.21976343]
#  T_diff Dem B: [1.18606284]
#  T_diff Dem c: [0.04061329]
#  T_diff Dem D: [0.32002555]
#
# T_diff Dem A: [0.16597908]
#  T_diff Dem B: [1.06056257]
#  T_diff Dem c: [0.03165483]
#  T_diff Dem D: [0.30081099]
#
# T_diff Dem A: [0.2441713]
#  T_diff Dem B: [0.98192674]
#  T_diff Dem c: [0.06333256]
#  T_diff Dem D: [0.30159727]
#
# T_diff Dem A: [0.15462978]
#  T_diff Dem B: [0.85747879]
#  T_diff Dem c: [0.0502677]
#  T_diff Dem D: [0.25959448]
#
# T_diff Dem A: [1.39473616]
#  T_diff Dem B: [1.01186023]
#  T_diff Dem c: [0.06206167]
#  T_diff Dem D: [0.17780373]
#
# T_diff Dem A: [0.47911176]
#  T_diff Dem B: [2.20379178]
#  T_diff Dem c: [0.05094279]
#  T_diff Dem D: [0.24295021]
#
# T_diff Dem A: [0.19572145]
#  T_diff Dem B: [1.66683256]
#  T_diff Dem c: [0.04928732]
#  T_diff Dem D: [0.34811236]
#
# T_diff Dem A: [0.18469569]
#  T_diff Dem B: [1.26782915]
#  T_diff Dem c: [0.03860449]
#  T_diff Dem D: [0.32466692]
#
# T_diff Dem A: [0.32625399]
#  T_diff Dem B: [1.62006953]
#  T_diff Dem c: [0.05219525]
#  T_diff Dem D: [0.17667657]
#
# T_diff Dem A: [0.76513977]
#  T_diff Dem B: [0.85641223]
#  T_diff Dem c: [0.05479981]
#  T_diff Dem D: [0.31527071]
#
# T_diff Dem A: [0.29919819]
#  T_diff Dem B: [0.98688659]
#  T_diff Dem c: [0.03910554]
#  T_diff Dem D: [0.16864715]
#
# T_diff Dem A: [0.28391884]
#  T_diff Dem B: [0.6299526]
#  T_diff Dem c: [0.04292157]
#  T_diff Dem D: [0.37374198]
#
# T_diff Dem A: [0.18626084]
#  T_diff Dem B: [1.31886812]
#  T_diff Dem c: [0.03054041]
#  T_diff Dem D: [0.36500888]
#
# T_diff Dem A: [0.17447071]
#  T_diff Dem B: [6.49540808]
#  T_diff Dem c: [0.04819317]
#  T_diff Dem D: [0.17147782]
#
# T_diff Dem A: [0.15670539]
#  T_diff Dem B: [2.63117823]
#  T_diff Dem c: [0.03435715]
#  T_diff Dem D: [0.15402947]
#
# T_diff Dem A: [0.23698624]
#  T_diff Dem B: [1.28496902]
#  T_diff Dem c: [0.02186071]
#  T_diff Dem D: [0.14569466]
#
# T_diff Dem A: [0.42147558]
#  T_diff Dem B: [1.57563311]
#  T_diff Dem c: [0.02826378]
#  T_diff Dem D: [0.22180184]
#
# T_diff Dem A: [0.45202757]
#  T_diff Dem B: [2.67008725]
#  T_diff Dem c: [0.0724984]
#  T_diff Dem D: [0.2375101]
#
# T_diff Dem A: [1.6960403]
#  T_diff Dem B: [-3.4562892]
#  T_diff Dem c: [0.04039164]
#  T_diff Dem D: [0.18168899]
#
# T_diff Dem A: [0.1931712]
#  T_diff Dem B: [1.97610198]
#  T_diff Dem c: [0.05073075]
#  T_diff Dem D: [0.79470118]
#
# T_diff Dem A: [0.24472088]
#  T_diff Dem B: [0.54508716]
#  T_diff Dem c: [0.02703342]
#  T_diff Dem D: [0.35766321]
#
# T_diff Dem A: [0.16914491]
#  T_diff Dem B: [1.06815756]
#  T_diff Dem c: [0.03829294]
#  T_diff Dem D: [0.34362601]
#
# T_diff Dem A: [0.17690344]
#  T_diff Dem B: [1.98086563]
#  T_diff Dem c: [0.06442385]
#  T_diff Dem D: [0.31734778]
#
# T_diff Dem A: [0.29700152]
#  T_diff Dem B: [0.85799616]
#  T_diff Dem c: [0.03478873]
#  T_diff Dem D: [0.16744668]
#
# T_diff Dem A: [0.43414354]
#  T_diff Dem B: [2.15989786]
#  T_diff Dem c: [0.0372552]
#  T_diff Dem D: [0.21928221]
#
# T_diff Dem A: [0.15440547]
#  T_diff Dem B: [0.83562752]
#  T_diff Dem c: [0.03387235]
#  T_diff Dem D: [0.2801716]
#
# T_diff Dem A: [0.30172482]
#  T_diff Dem B: [1.10718086]
#  T_diff Dem c: [0.03990457]
#  T_diff Dem D: [0.15938903]
#
# T_diff Dem A: [0.2747129]
#  T_diff Dem B: [0.7544542]
#  T_diff Dem c: [0.02695849]
#  T_diff Dem D: [0.15432405]
#
# T_diff Dem A: [0.16793151]
#  T_diff Dem B: [4.4670764]
#  T_diff Dem c: [0.03164588]
#  T_diff Dem D: [0.16467541]
#
# T_diff Dem A: [0.30262841]
#  T_diff Dem B: [3.14541455]
#  T_diff Dem c: [0.05442951]
#  T_diff Dem D: [0.15260902]
#
# T_diff Dem A: [-0.05672639]
#  T_diff Dem B: [0.1540146]
#  T_diff Dem c: [-0.01638579]
#  T_diff Dem D: [-0.05544114]
#
# T_diff Dem A: [-0.07531165]
#  T_diff Dem B: [2.12996726]
#  T_diff Dem c: [-0.01433217]
#  T_diff Dem D: [-0.07359895]
#
# T_diff Dem A: [-0.10206974]
#  T_diff Dem B: [-0.33921043]
#  T_diff Dem c: [-0.01140075]
#  T_diff Dem D: [-0.06350314]
#
# T_diff Dem A: [-0.05354875]
#  T_diff Dem B: [-0.33110685]
#  T_diff Dem c: [-0.01473236]
#  T_diff Dem D: [-0.1390009]
#
# T_diff Dem A: [-0.05240596]
#  T_diff Dem B: [-0.67262777]
#  T_diff Dem c: [-0.01301637]
#  T_diff Dem D: [-0.35120079]
#
# T_diff Dem A: [-0.08207207]
#  T_diff Dem B: [-0.24225001]
#  T_diff Dem c: [-0.0111825]
#  T_diff Dem D: [-0.04388309]
#
# T_diff Dem A: [-0.09582944]
#  T_diff Dem B: [-0.34785715]
#  T_diff Dem c: [-0.01185506]
#  T_diff Dem D: [-0.04840789]
#
# T_diff Dem A: [-0.0957064]
#  T_diff Dem B: [-0.25870063]
#  T_diff Dem c: [-0.01466238]
#  T_diff Dem D: [-0.05370956]
#
# T_diff Dem A: [-0.0524009]
#  T_diff Dem B: [-0.41557956]
#  T_diff Dem c: [-0.01482574]
#  T_diff Dem D: [-0.11001495]
#
# T_diff Dem A: [-0.05516856]
#  T_diff Dem B: [-0.58325642]
#  T_diff Dem c: [-0.01331448]
#  T_diff Dem D: [-0.11015644]
#
# T_diff Dem A: [-0.09846386]
#  T_diff Dem B: [-0.28504646]
#  T_diff Dem c: [-0.00909919]
#  T_diff Dem D: [-0.06417613]
#
# T_diff Dem A: [-0.10115539]
#  T_diff Dem B: [-0.35778644]
#  T_diff Dem c: [-0.01233774]
#  T_diff Dem D: [-0.05162008]
#
# T_diff Dem A: [-0.0514686]
#  T_diff Dem B: [-0.34153112]
#  T_diff Dem c: [-0.0082275]
#  T_diff Dem D: [-0.09204259]
#
# T_diff Dem A: [-0.10588558]
#  T_diff Dem B: [-0.50804274]
#  T_diff Dem c: [-0.01037556]
#  T_diff Dem D: [-0.04753662]
#
# T_diff Dem A: [-0.13157451]
#  T_diff Dem B: [-0.7653091]
#  T_diff Dem c: [-0.0103564]
#  T_diff Dem D: [-0.04539089]
#
# T_diff Dem A: [-0.06053833]
#  T_diff Dem B: [-1.79204369]
#  T_diff Dem c: [-0.01475047]
#  T_diff Dem D: [-0.05944738]
#
# T_diff Dem A: [-0.13178009]
#  T_diff Dem B: [-0.31898835]
#  T_diff Dem c: [-0.01731077]
#  T_diff Dem D: [-0.08243573]
#
# T_diff Dem A: [-0.09478026]
#  T_diff Dem B: [-0.21684889]
#  T_diff Dem c: [-0.01581207]
#  T_diff Dem D: [-0.10182568]
#
# T_diff Dem A: [-0.06529767]
#  T_diff Dem B: [-0.247329]
#  T_diff Dem c: [-0.01031845]
#  T_diff Dem D: [-0.1043391]
#
# T_diff Dem A: [-0.0978362]
#  T_diff Dem B: [-0.33441954]
#  T_diff Dem c: [-0.0101466]
#  T_diff Dem D: [-0.04984509]
#
# T_diff Dem A: [-0.0704854]
#  T_diff Dem B: [-0.42289505]
#  T_diff Dem c: [-0.01259367]
#  T_diff Dem D: [-0.10713158]
#
# T_diff Dem A: [-0.0528122]
#  T_diff Dem B: [-0.37454444]
#  T_diff Dem c: [-0.00977706]
#  T_diff Dem D: [-0.10138784]
#
# T_diff Dem A: [-0.07851755]
#  T_diff Dem B: [-0.34320556]
#  T_diff Dem c: [-0.01972878]
#  T_diff Dem D: [-0.09999845]
#
# T_diff Dem A: [-0.04897399]
#  T_diff Dem B: [-0.29626386]
#  T_diff Dem c: [-0.01555519]
#  T_diff Dem D: [-0.0861148]
#
# T_diff Dem A: [-0.19264809]
#  T_diff Dem B: [-0.46892047]
#  T_diff Dem c: [-0.02186882]
#  T_diff Dem D: [-0.0671131]
#
# T_diff Dem A: [-0.16767498]
#  T_diff Dem B: [-0.86565326]
#  T_diff Dem c: [-0.01609172]
#  T_diff Dem D: [-0.07970926]
#
# T_diff Dem A: [-0.06273468]
#  T_diff Dem B: [-0.61986116]
#  T_diff Dem c: [-0.01535439]
#  T_diff Dem D: [-0.11892343]
#
# T_diff Dem A: [-0.05900027]
#  T_diff Dem B: [-0.45589195]
#  T_diff Dem c: [-0.01196938]
#  T_diff Dem D: [-0.10997281]
#
# T_diff Dem A: [-0.11128226]
#  T_diff Dem B: [-0.59951836]
#  T_diff Dem c: [-0.0162599]
#  T_diff Dem D: [-0.05649201]
#
# T_diff Dem A: [-0.26265982]
#  T_diff Dem B: [-0.29541765]
#  T_diff Dem c: [-0.0170794]
#  T_diff Dem D: [-0.10449699]
#
# T_diff Dem A: [-0.10087415]
#  T_diff Dem B: [-0.34559059]
#  T_diff Dem c: [-0.01212289]
#  T_diff Dem D: [-0.05374862]
#
# T_diff Dem A: [-0.09352832]
#  T_diff Dem B: [-0.21194127]
#  T_diff Dem c: [-0.01332012]
#  T_diff Dem D: [-0.12240266]
#
# T_diff Dem A: [-0.0598024]
#  T_diff Dem B: [-0.47944945]
#  T_diff Dem c: [-0.00946908]
#  T_diff Dem D: [-0.12408393]
#
# T_diff Dem A: [-0.0554235]
#  T_diff Dem B: [-3.22190044]
#  T_diff Dem c: [-0.01492104]
#  T_diff Dem D: [-0.0545509]
#
# T_diff Dem A: [-0.04977136]
#  T_diff Dem B: [-1.05890094]
#  T_diff Dem c: [-0.0106025]
#  T_diff Dem D: [-0.04891543]
#
# T_diff Dem A: [-0.07795987]
#  T_diff Dem B: [-0.46269094]
#  T_diff Dem c: [-0.00669339]
#  T_diff Dem D: [-0.04601013]
#
# T_diff Dem A: [-0.14845551]
#  T_diff Dem B: [-0.58349031]
#  T_diff Dem c: [-0.00876837]
#  T_diff Dem D: [-0.0719166]
#
# T_diff Dem A: [-0.16253273]
#  T_diff Dem B: [-1.07569266]
#  T_diff Dem c: [-0.02295025]
#  T_diff Dem D: [-0.0776511]
#
# T_diff Dem A: [-0.23939924]
#  T_diff Dem B: [-0.47400666]
#  T_diff Dem c: [-0.01096248]
#  T_diff Dem D: [-0.04987701]
#
# T_diff Dem A: [-0.06482404]
#  T_diff Dem B: [-0.82218161]
#  T_diff Dem c: [-0.01640818]
#  T_diff Dem D: [-0.18692843]
#
# T_diff Dem A: [-0.07994109]
#  T_diff Dem B: [-0.18145214]
#  T_diff Dem c: [-0.00830946]
#  T_diff Dem D: [-0.11671156]
#
# T_diff Dem A: [-0.05424473]
#  T_diff Dem B: [-0.3821832]
#  T_diff Dem c: [-0.01192912]
#  T_diff Dem D: [-0.11214372]
#
# T_diff Dem A: [-0.05648222]
#  T_diff Dem B: [-0.75518743]
#  T_diff Dem c: [-0.02007239]
#  T_diff Dem D: [-0.10792249]
#
# T_diff Dem A: [-0.10032621]
#  T_diff Dem B: [-0.29730327]
#  T_diff Dem c: [-0.01077453]
#  T_diff Dem D: [-0.05340093]
#
# T_diff Dem A: [-0.15403034]
#  T_diff Dem B: [-0.84228823]
#  T_diff Dem c: [-0.01166453]
#  T_diff Dem D: [-0.0714345]
#
# T_diff Dem A: [-0.04902965]
#  T_diff Dem B: [-0.28927397]
#  T_diff Dem c: [-0.01046872]
#  T_diff Dem D: [-0.09336286]
#
# T_diff Dem A: [-0.10228922]
#  T_diff Dem B: [-0.39694569]
#  T_diff Dem c: [-0.01243248]
#  T_diff Dem D: [-0.05105736]
#
# T_diff Dem A: [-0.09229973]
#  T_diff Dem B: [-0.2588337]
#  T_diff Dem c: [-0.00831129]
#  T_diff Dem D: [-0.04906203]
#
# T_diff Dem A: [-0.0533526]
#  T_diff Dem B: [-2.04978424]
#  T_diff Dem c: [-0.00973259]
#  T_diff Dem D: [-0.05227606]
#
# T_diff Dem A: [-0.10933751]
#  T_diff Dem B: [-1.29763533]
#  T_diff Dem c: [-0.01697535]
#  T_diff Dem D: [-0.04882753]
#
# ########################## probabilistic comaprison: ##############################
#
# q_modifier: 0.7
# T_diff Dem A: mean: 0.320411, std: 0.278607
# T_diff Dem B: mean: 1.576392, std: 1.464184
# T_diff Dem C: mean: 0.042193, std: 0.010959
# T_diff Dem D: mean: 0.278834, std: 0.223719
# q_modifier: 1.3
# T_diff Dem A: mean: 0.093414, std: 0.047194
# T_diff Dem B: mean: 0.617416, std: 0.657955
# T_diff Dem C: mean: 0.013152, std: 0.003579
# T_diff Dem D: mean: 0.085424, std: 0.048943

# %%
# 8. calculate mean deviations and deviation variances
print(f'########################## probabilistic comaprison: ############################## \n')
for mod_ind, mod in enumerate(q_modifier):
    # 10 compare results over multiple runs:
    diff_a = Ta_ss[:, mod_ind] - Ta_qss[:, mod_ind]
    diff_b = Tb_ss[:, mod_ind] - Tb_qss[:, mod_ind]
    diff_c = Tc_ss[:, mod_ind] - Tc_qss[:, mod_ind]
    diff_d = Td_ss[:, mod_ind] - Td_qss[:, mod_ind]
    print(f'q_modifier: {mod} \n'
          f'T_diff Dem A: mean: {np.mean(np.abs(diff_a)):2f}, std: {np.std(diff_a):2f} \n'
          f'T_diff Dem B: mean: {np.mean(np.abs(diff_b)):2f}, std: {np.std(diff_b):2f} \n'
          f'T_diff Dem C: mean: {np.mean(np.abs(diff_c)):2f}, std: {np.std(diff_c):2f} \n'
          f'T_diff Dem D: mean: {np.mean(np.abs(diff_d)):2f}, std: {np.std(diff_d):2f}')
# Out:
# ########################## probabilistic comaprison: ##############################
#
# q_modifier: 0.7
# T_diff Dem A: mean: 0.320411, std: 0.278607
# T_diff Dem B: mean: 1.576392, std: 1.464184
# T_diff Dem C: mean: 0.042193, std: 0.010959
# T_diff Dem D: mean: 0.278834, std: 0.223719
# q_modifier: 1.3
# T_diff Dem A: mean: 0.093414, std: 0.047194
# T_diff Dem B: mean: 0.617416, std: 0.657955
# T_diff Dem C: mean: 0.013152, std: 0.003579
# T_diff Dem D: mean: 0.085424, std: 0.048943
